# %% [markdown]
# # RSA Practicum Project - Self Segregation
# Perform Data Analysis on Rutgers Resident Student Life data (2010-2018) and search for patterns of self-segregation.
#
# Data Analytics Summer 2018 Practicum Residence Life Trends Analysis This is a communication site between Student Affairs Research and Assessment and graduate students in MBS (Data Analytics). The purpose of this assessment is to conduct a longitudinal trends examination of student demographic characteristics in the residence halls at Rutgers University-New Brunswick and determine whether there are patterns of self-segregation. Specifically, the assessment seeks to answer the following questions:
#
# (a) What are the characteristics to describe students living in particular residence halls? How do these characteristics vary by building and campus?
#
# (b) How have the characteristics of students living in specific buildings and locations changed over time?
#
# (c) What characteristics are most salient with respect to time, building and location?
#
# (d) To what extent does race/ethnicity, socio-economic status, or academic affiliation predict students’ residence location and building type? How have these patterns changed over time?
#
# The dataset spans eight academic years. Each datafile (year) ranges from 13,000 to close to 16,000 cases. Residence Life provided information on room category, campus, building, room number, room type, gender, admit term, and class year. The following student characteristics will be merged into the datafile: residence hall costs, academic affiliation (e.g., school), race/ethnicity, and financial aid marker (e.g., pell grant).

# %% [markdown]
# #READ
# This code is the code we ran on the new data we received on June 29th
# Followed by SAT Converter and Merge GPA change files
# Another code was run on initial data named RSAPracticum.ipynb

# %%
#Import needed Libraries to perform exploratory analysis
import pandas as pd
import numpy

# %%
xls = pd.ExcelFile('xxxxxxxx') #Load Excel file

# %%
#Extract Data from Excel file into individual df
Year2010_2011 =pd.read_excel(xls, xls.sheet_names[0])
Year2011_2012 =pd.read_excel(xls, xls.sheet_names[1]) 
Year2012_2013 =pd.read_excel(xls, xls.sheet_names[2]) 
Year2013_2014 =pd.read_excel(xls, xls.sheet_names[3])
Year2014_2015 =pd.read_excel(xls, xls.sheet_names[4]) 
Year2015_2016 =pd.read_excel(xls, xls.sheet_names[5]) 
Year2016_2017 =pd.read_excel(xls, xls.sheet_names[6]) 
Year2017_2018 =pd.read_excel(xls, xls.sheet_names[7])

# %%
#Shows Columns in 2011-2012,2017_2018
print("______________________________Column Names_____________________________\n", Year2017_2018.columns,"\n"'Columns:',
      len(Year2017_2018.columns))
      
print("______________________________Column Names_____________________________\n", Year2011_2012.columns,'\n','Columns:',
      len(Year2017_2018.columns))
# Out:
# ______________________________Column Names_____________________________
#  Index(['Room Category', 'Campus', 'Building', 'Wing', 'Room', 'Room Type',
#        'RUID', 'SURE_ReportingDt', 'Last Name', 'First Name', 'Gender',
#        'Admit Term', 'Class Year', 'Enrollment Term Referenced',
#        'Citizenship Status', 'Original State Residency',
#        'Original State Residency Category', 'Major Code', 'CIP Code',
#        'CIP Category', 'School', 'IPEDS Race/Ethnicity', 'Pell Grant Status',
#        'First Generation Status', 'Country of Origin', 'City', 'State',
#        'Confirmed LLC', 'Honors Indicator'],
#       dtype='object')
# Columns: 29
# ______________________________Column Names_____________________________
#  Index(['Room Category', 'Campus', 'Building', 'Wing', 'Room', 'Room Type',
#        'RUID', 'SURE_ReportingDt', 'Last Name', 'First Name', 'Gender',
#        'Admit Term', 'Class Year', 'Enrollment Term Referenced',
# ...

# %%
#summing missing values
null10_11 =Year2010_2011.isnull().sum()
b= Year2011_2012.isnull().sum()

# %%
b
# Out:
# Room Category                            0
# Campus                                   0
# Building                                 0
# Wing                                  6813
# Room                                     0
# Room Type                                0
# RUID                                     0
# SURE_ReportingDt                         0
# Last Name                                0
# First Name                               0
# Gender                                   0
# Admit Term                            3688
# Class Year                               6
# Enrollment Term Referenced               0
# Citizenship Status                       0
# Original State Residency                 0
# Original State Residency Category        0
# Major Code                               0
# CIP Code                                 0
# CIP Category                             0
# School                                   0
# IPEDS Race/Ethnicity                     0
# ...

# %%
#turning series to frame
null10_11.to_frame
# Out:
# <bound method Series.to_frame of Room Category                            0
# Campus                                   0
# Building                                 0
# Wing                                  6816
# Room                                     0
# Room Type                                0
# RUID                                     0
# SURE_ReportingDt                         0
# Last Name                                0
# First Name                               0
# Gender                                   0
# Admit Term                            7459
# Class Year                               9
# Enrollment Term Referenced               0
# Citizenship Status                       0
# Original State Residency                 0
# Original State Residency Category        0
# Major Code                               0
# CIP Code                                 0
# CIP Category                             0
# School                                   0
# ...

# %%
#Creating frame of missing values
null10_11frame=pd.DataFrame(null10_11)
null10_11frame[1]=pd.DataFrame(Year2011_2012.isnull().sum())
null10_11frame[2]=pd.DataFrame(Year2012_2013.isnull().sum())
null10_11frame[3]=pd.DataFrame(Year2013_2014.isnull().sum())
null10_11frame[4]=pd.DataFrame(Year2014_2015.isnull().sum())
null10_11frame[5]=pd.DataFrame(Year2015_2016.isnull().sum())
null10_11frame[6]=pd.DataFrame(Year2016_2017.isnull().sum())
null10_11frame[7]=pd.DataFrame(Year2017_2018.isnull().sum())
null10_11frame.columns = ["10_11","11_12","12_13","13_14","14_15","15_16","16_17","17_18"]
null10_11frame
# Out:
#                                    10_11  11_12  12_13  13_14  14_15  15_16  \
# Room Category                          0      0      0      0      0      0
# Campus                                 0      0      0      0      0      0
# Building                               0      0      0      0      0      0
# Wing                                6816   6813   6684   6789   6216   6415
# Room                                   0      0      0      0      0      0
# Room Type                              0      0      0      0      0      0
# RUID                                   0      0      0      0      0      0
# SURE_ReportingDt                       0      0      0      0      0      0
# Last Name                              0      0      0      0      0      0
# First Name                             0      0      0      0      0      0
# Gender                                 0      0      0      0      0      0
# ...

# %%
#Seeing length of all frames combined
len(Year2010_2011.index) + len(Year2011_2012.index) + len(Year2012_2013.index)\
+len(Year2013_2014.index)+len(Year2014_2015.index)+len(Year2015_2016.index)\
+len(Year2016_2017.index)+len(Year2017_2018)
# Out:
# 119978

# %%
#looking to replace value
Year2014_2015.replace("No Finaid", "Not PELL")
Year2014_2015.iloc[6622:6623,-2:-1] = "Not PELL"

# %%
#Created an array of all the buildings listed accross all data sets
a = numpy.array([(Year2010_2011['Building'].unique()),numpy.sort(Year2011_2012['Building'].unique()),\
                         numpy.sort(Year2012_2013['Building'].unique()),numpy.sort(Year2013_2014['Building'].unique()),\
                        numpy.sort(Year2014_2015['Building'].unique()),numpy.sort(Year2015_2016['Building'].unique()),\
                        numpy.sort(Year2016_2017['Building'].unique()),numpy.sort(Year2017_2018['Building'].unique())])

# %%
a
# Out:
# array([array(['Easton Avenue Apartments', 'Quad I Res. Hall', 'NEWELL',
#        'Davidson Hall', 'Henderson Apartments', 'Judson Suites',
#        'Lynton Tower Res. Hall', 'NICHOLAS', 'Silvers Apartments',
#        'Quad II Res. Hall', 'Katzenbach Res. Hall', 'Winkler Suites',
#        'Mattia Hall', 'New Gibbons Res. Hall', 'Woodbury Res. Hall',
#        'Frelinghuysen Hall', 'Quad III Res. Hall', 'Clothier Hall',
#        'McCormick Suites', 'Rockoff', 'Tinsley', 'Thomas Suites',
#        'Lippincott Res. Hall', 'Nichols Apartments', 'Morrow Suites',
#        'Demarest Hall', 'Mettler', 'Campbell Hall', 'Barr Hall',
#        'Voorhees Res. Hall', 'Starkey Apartments', 'Jameson Res. Hall',
#        'Brett Hall', 'Metzger Hall', 'Hardenbergh Hall', 'Crosby Suites',
#        'Allen Hall', 'Richardson Apartments', 'Hegeman Hall',
#        'Bunting-Cobb Res. Hall', 'Stonier', 'Perry Res. Hall',
#        'HELYAR HOUSE', 'Wessels', 'Old Gibbons Res. Hall', 'LEUPP',
# ...

# %%
#set all values to list
z =[]
for i in range(len(a)):
    z += a[i].tolist()

# %%
#Created a sorted ordered list
z =set(z)
sorted(z)
# Out:
# ['Allen Hall',
#  'BEST Hall',
#  'Barr Hall',
#  'Brett Hall',
#  'Buell Apartments',
#  'Bunting-Cobb Res. Hall',
#  'Campbell Hall',
#  'Clothier Hall',
#  'Crosby Suites',
#  'Davidson Hall',
#  'Demarest Hall',
#  'Easton Avenue Apartments',
#  'Ford Hall',
#  'Frelinghuysen Hall',
#  'HELYAR HOUSE',
#  'Hardenbergh Hall',
#  'Hegeman Hall',
#  'Henderson Apartments',
#  'Honors College',
#  'Jameson Res. Hall',
#  'Johnson Apartments',
#  'Judson Suites',
#  'Katzenbach Res. Hall',
#  'LEUPP',
#  'Leupp',
#  'Lippincott Res. Hall',
#  'Livingston Apartments',
#  'Lynton Tower Res. Hall',
#  'Marvin Apartments',
#  'Mattia Hall',
#  'McCormick Suites',
#  'Mettler',
#  'Metzger Hall',
#  'Morrow Suites',
#  'NEWELL',
#  'NICHOLAS',
#  'New Gibbons Res. Hall',
#  'Nichols Apartments',
#  'Old Gibbons Res. Hall',
#  'Pell',
#  'Perry Res. Hall',
#  'Quad I Res. Hall',
#  'Quad II Res. Hall',
#  'Quad III Res. Hall',
#  'Richardson Apartments',
#  'Rockoff',
# ...

# %%
#Attempt to save buildings to csv
import csv
with open('buildings.csv', 'w', newline='') as csvfile:
    buildingwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    buildingwriter.writerow(z)
    
#csv = open("buildings.csv", "w")
#for building in z:
#    csv.write(building)

#print (str(z))

# %%
#number of buldings in system
len(z)
# Out:
# 57

# %%
# Testing Code to See how many types of room types per buidling for a year 
pd.DataFrame(Year2014_2015[["Building","Room Type","XXXX"]].groupby(["Building","Room Type"]).count())
#Seeing how many types of rooms in
# Out:
#                                     RUID
# Building                 Room Type
# Allen Hall               DBL         212
#                          SGL           5
# BEST Hall                DBL         440
#                          SGL          11
#                          STESGL       44
# Barr Hall                DBL         214
#                          SGL           5
# Brett Hall               DBL         192
#                          SGL          22
# Buell Apartments         4BD         367
# Bunting-Cobb Res. Hall   DBL         101
#                          DBL1          6
#                          SGL           6
# Campbell Hall            DBL         311
#                          SGL          14
# Clothier Hall            DBL         359
#                          SGL          12
# Crosby Suites            STE         161
#                          STE5         15
# Davidson Hall            DBL         294
#                          SGL          34
# ...

# %%
Year2010_2011.loc[Year2010_2011['Room Category'] != "Graduate"][["Building","Room Type","XXXX"]].groupby(["Building","Room Type"]).count()
# Out:
#                                     RUID
# Building                 Room Type
# Allen Hall               DBL         216
#                          SGL           4
# Barr Hall                DBL         218
#                          SGL           4
# Brett Hall               DBL         188
#                          SGL          21
# Bunting-Cobb Res. Hall   DBL          97
#                          DBL1          8
#                          SGL           6
# Campbell Hall            DBL         303
#                          SGL          15
# Clothier Hall            DBL         359
#                          SGL          13
# Crosby Suites            STE         160
#                          STE5         10
# Davidson Hall            DBL         294
#                          SGL          34
# Demarest Hall            DBL         171
#                          SGL           4
# Easton Avenue Apartments 2BD         646
# Frelinghuysen Hall       DBL         305
# ...

# %%
Year2017_2018.loc[Year2017_2018["Gender"].isnull()]["Gender"]
# Out:
# 9580     NaN
# 10800    NaN
# Name: Gender, dtype: object

# %%
#Correcting Gender on two instances
#9580 & 10800
Year2017_2018.loc[9580,"Gender"] = 'Female'
Year2017_2018.loc[10800,"Gender"] = 'Female'

# %%
Year2017_2018.loc[9580]
# Out:
# Room Category                                              Continuing
# Campus                                                Douglass Campus
# Building                                        New Gibbons Res. Hall
# Wing                                                              B-5
# Room                                                              320
# Room Type                                                         SGL
# RUID                                                        177001027
# SURE_ReportingDt                                                92017
# Last Name                                                       Price
# First Name                                                    Kathryn
# Gender                                                         Female
# Admit Term                                                        179
# Class Year                                                       2021
# ...

# %%
#Mislabeled Room Categories found in 2010-2011 Data
Year2010_2011[Year2010_2011["XXXX"]=='132006903'] 
#Year2010_2011[Year2010_2011["XXXX"]=='134007768']
#Rows 147, 2911, 7532 & 13227
# Out:
#      Room Category        Campus      Building Wing Room Room Type       RUID  \
# 7523      Graduate  Busch Campus  Metzger Hall  NaN  432       DBL  132006903
#
#       SURE_ReportingDt Last Name First Name       ...        CIP Category  \
# 7523             92010   Matheis   Adrianna       ...          Undeclared
#
#                      School IPEDS Race/Ethnicity Pell Grant Status  \
# 7523  School of Engineering          Two or More              PELL
#
#      First Generation Status Country of Origin         City State  \
# 7523        First Generation               USA  East Orange    NJ
#
#      Confirmed LLC Honors Indicator
# 7523           NaN              NaN
#
# [1 rows x 29 columns]

# %%
#Addressing mislabeled found categories
Year2010_2011.loc[147,"Room Category"]= "New"
Year2010_2011.loc[2911,"Room Category"]= "New"
Year2010_2011.loc[7532,"Room Category"]= "New"
Year2010_2011.loc[13227,"Room Category"]= "New"

# %%
Year2010_2011.loc[Year2010_2011['Room Category'] != "Graduate"][["Building","Room Type","XXXX"]].groupby(["Building","Room Type"]).count()
# Out:
#                                     RUID
# Building                 Room Type
# Allen Hall               DBL         218
#                          SGL           4
# Barr Hall                DBL         218
#                          SGL           4
# Brett Hall               DBL         188
#                          SGL          21
# Bunting-Cobb Res. Hall   DBL          97
#                          DBL1          8
#                          SGL           6
# Campbell Hall            DBL         303
#                          SGL          15
# Clothier Hall            DBL         359
#                          SGL          13
# Crosby Suites            STE         160
#                          STE5         10
# Davidson Hall            DBL         294
#                          SGL          34
# Demarest Hall            DBL         171
#                          SGL           4
# Easton Avenue Apartments 2BD         646
# Frelinghuysen Hall       DBL         305
# ...

# %%
#Removing Graduate Housing
Year2010_2011 = Year2010_2011.loc[Year2010_2011['Room Category'] != "Graduate"]
Year2011_2012 =Year2011_2012.loc[Year2011_2012['Room Category'] != "Graduate"]
Year2012_2013 =Year2012_2013.loc[Year2012_2013['Room Category'] != "Graduate"]
Year2013_2014 =Year2013_2014.loc[Year2013_2014['Room Category'] != "Graduate"]
Year2014_2015 = Year2014_2015.loc[Year2014_2015['Room Category'] != "Graduate"]
Year2015_2016 =Year2015_2016.loc[Year2015_2016['Room Category'] != "Graduate"]
Year2016_2017 =Year2016_2017.loc[Year2016_2017['Room Category'] != "Graduate"]
Year2017_2018 =Year2017_2018.loc[Year2017_2018['Room Category'] != "Graduate"]

# %%
#Getting count per building and pell grant status
#pd.DataFrame(Year2011_2012[["Building","Pell Grant Status","XXXX"]].groupby(["Building","Pell Grant Status"]).count())
Pell_Grant_Dorm_per_Year =pd.concat([pd.DataFrame(Year2010_2011[["Building","Pell Grant Status","XXXX"]].groupby(["Building","Pell Grant Status"]).count()),\
           pd.DataFrame(Year2011_2012[["Building","Pell Grant Status","XXXX"]].groupby(["Building","Pell Grant Status"]).count()),\
          pd.DataFrame(Year2012_2013[["Building","Pell Grant Status","XXXX"]].groupby(["Building","Pell Grant Status"]).count()),\
          pd.DataFrame(Year2013_2014[["Building","Pell Grant Status","XXXX"]].groupby(["Building","Pell Grant Status"]).count()),\
          pd.DataFrame(Year2014_2015[["Building","Pell Grant Status","XXXX"]].groupby(["Building","Pell Grant Status"]).count()),\
          pd.DataFrame(Year2015_2016[["Building","Pell Grant Status","XXXX"]].groupby(["Building","Pell Grant Status"]).count()),\
          pd.DataFrame(Year2016_2017[["Building","Pell Grant Status","XXXX"]].groupby(["Building","Pell Grant Status"]).count())], axis=1)

Pell_Grant_Dorm_per_Year.columns= [["10_11","11_12","12_13","13_14", "14_15","15_16","16_17"]]
#Pell_Grant_Dorm_per_Year.transpose().
#Pell_Grant_Dorm_per_Year.transpose().describe()
Pell_Grant_Dorm_per_Year
# Out:
#                                               10_11  11_12  12_13  13_14  \
# Building                   Pell Grant Status
# Allen Hall                 Not PELL           160.0  153.0  157.0  146.0
#                            PELL                62.0   66.0   60.0   72.0
# BEST Hall                  Not PELL             NaN  346.0  367.0  380.0
#                            PELL                 NaN  151.0  130.0  117.0
# Barr Hall                  Not PELL           149.0  156.0  165.0  161.0
#                            PELL                73.0   65.0   56.0   60.0
# Brett Hall                 Not PELL           185.0  193.0  186.0  180.0
#                            PELL                24.0   23.0   27.0   36.0
# Bunting-Cobb Res. Hall     Not PELL            78.0   77.0   77.0   75.0
#                            PELL                33.0   34.0   34.0   34.0
# Campbell Hall              Not PELL           211.0  202.0  204.0  206.0
# ...

# %%
#See what Dorms were used for each year and what room types exist in each building, , this columns used to create price matrix in excel
Dorm_Type_per_Year =pd.concat([pd.DataFrame(Year2010_2011[["Building","Room Type","XXXX"]].groupby(["Building","Room Type"]).count()),\
           pd.DataFrame(Year2011_2012[["Building","Room Type","XXXX"]].groupby(["Building","Room Type"]).count()),\
          pd.DataFrame(Year2012_2013[["Building","Room Type","XXXX"]].groupby(["Building","Room Type"]).count()),\
          pd.DataFrame(Year2013_2014[["Building","Room Type","XXXX"]].groupby(["Building","Room Type"]).count()),\
          pd.DataFrame(Year2014_2015[["Building","Room Type","XXXX"]].groupby(["Building","Room Type"]).count()),\
          pd.DataFrame(Year2015_2016[["Building","Room Type","XXXX"]].groupby(["Building","Room Type"]).count()),\
          pd.DataFrame(Year2016_2017[["Building","Room Type","XXXX"]].groupby(["Building","Room Type"]).count()),
          pd.DataFrame(Year2017_2018[["Building","Room Type","XXXX"]].groupby(["Building","Room Type"]).count())], axis=1)

Dorm_Type_per_Year.columns= [["10_11","11_12","12_13","13_14", "14_15","15_16","16_17","17_18"]]
Dorm_Type_per_Year
# Out:
#                                       10_11  11_12  12_13  13_14  14_15  \
# Building                   Room Type
# Allen Hall                 DBL        218.0  214.0  209.0  210.0  212.0
#                            DBL1         NaN    NaN    3.0    3.0    NaN
#                            SGL          4.0    5.0    5.0    5.0    5.0
# BEST Hall                  DBL          NaN  442.0  442.0  442.0  440.0
#                            SGL          NaN   11.0   11.0   11.0   11.0
#                            STESGL       NaN   44.0   44.0   44.0   44.0
# Barr Hall                  DBL        218.0  217.0  216.0  216.0  214.0
#                            SGL          4.0    4.0    5.0    5.0    5.0
# Brett Hall                 DBL        188.0  194.0  192.0  194.0  192.0
#                            SGL         21.0   22.0   21.0   22.0   22.0
# Bunting-Cobb Res. Hall     DBL         97.0   98.0   99.0   97.0  101.0
# ...

# %%
Dorm_Type_per_Year.to_csv("DormTypePerYear2.csv")

# %%
Dorm_per_Year =pd.concat([pd.DataFrame(Year2010_2011[["Building","XXXX"]].groupby("Building").count()),\
                          pd.DataFrame(Year2011_2012[["Building","XXXX"]].groupby("Building").count()),\
                          pd.DataFrame(Year2012_2013[["Building","XXXX"]].groupby("Building").count()),\
                          pd.DataFrame(Year2013_2014[["Building","XXXX"]].groupby("Building").count()),\
                          pd.DataFrame(Year2014_2015[["Building","XXXX"]].groupby("Building").count()),\
                          pd.DataFrame(Year2015_2016[["Building","XXXX"]].groupby("Building").count()),\
                          pd.DataFrame(Year2016_2017[["Building","XXXX"]].groupby("Building").count()),\
                          pd.DataFrame(Year2017_2018[["Building","XXXX"]].groupby("Building").count())], axis=1)

Dorm_per_Year.columns= [["10_11","11_12","12_13","13_14", "14_15","15_16","16_17","17_18"]]
#Pell_Grant_Dorm_per_Year.transpose().
#Pell_Grant_Dorm_per_Year.transpose().describe()
Dorm_per_Year
#Dorm_per_Year.to_csv("DormPerYear.csv")
# Out:
# C:\Users\ivani\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.
#                             10_11  11_12   12_13   13_14   14_15   15_16  \
# Allen Hall                  222.0  219.0   217.0   218.0   217.0   219.0
# BEST Hall                     NaN  497.0   497.0   497.0   495.0   488.0
# Barr Hall                   222.0  221.0   221.0   221.0   219.0   219.0
# Brett Hall                  209.0  216.0   213.0   216.0   214.0   214.0
# Bunting-Cobb Res. Hall      111.0  111.0   111.0   109.0   113.0   110.0
# Campbell Hall               318.0  317.0   310.0   326.0   325.0   323.0
# Clothier Hall               372.0  372.0   362.0   377.0   371.0   374.0
# ...

# %%
#Creating a test year
Year2010_2011test= Year2010_2011

# %%
#creating csv for Kevin
Year2010_2011_ed = Year2010_2011
Year2011_2012_ed = Year2011_2012
Year2012_2013_ed = Year2012_2013
Year2013_2014_ed = Year2013_2014
Year2014_2015_ed = Year2014_2015
Year2015_2016_ed = Year2015_2016
Year2016_2017_ed = Year2016_2017
Year2017_2018_ed = Year2017_2018
#Adding Years as column
Year2010_2011_ed['Year_Of_Occupancy'] = '2010-2011'
Year2011_2012_ed['Year_Of_Occupancy'] = '2011-2012'
Year2012_2013_ed['Year_Of_Occupancy'] = '2012-2013'
Year2013_2014_ed['Year_Of_Occupancy'] = '2013-2014'
Year2014_2015_ed['Year_Of_Occupancy'] = '2014-2015'
Year2015_2016_ed['Year_Of_Occupancy'] = '2015-2016'
Year2016_2017_ed['Year_Of_Occupancy'] = '2016-2017'
Year2017_2018_ed['Year_Of_Occupancy'] = '2017-2018'

#Appending all to one datafile
df_year1 = Year2010_2011_ed
df_year1_all = df_year1.append([Year2011_2012_ed, Year2012_2013_ed,Year2013_2014_ed,Year2014_2015_ed,Year2015_2016_ed,Year2016_2017_ed,Year2017_2018_ed])
df_year1_all
# Out:
#              Room Category                 Campus                    Building  \
# 0               Continuing  College Avenue Campus    Easton Avenue Apartments
# 1               Continuing      Livingston Campus            Quad I Res. Hall
# 2               Continuing            Cook Campus                      NEWELL
# 3               Continuing           Busch Campus               Davidson Hall
# 5               Continuing            Cook Campus                      NEWELL
# 6               Continuing           Busch Campus               Judson Suites
# 8               Continuing            Cook Campus                    NICHOLAS
# 9               Continuing           Busch Campus          Silvers Apartments
# 10     Continuing/Transfer      Livingston Campus           Quad II Res. Hall
# 11              Continuing        Douglass Campus        Katzenbach Res. Hall
# 12              Continuing           Busch Campus              Winkler Suites
# ...

# %%
df_year1_all.to_csv("RSAdatatempmerge2.csv")

# %%
#Importing data price excel file
prices = pd.read_csv("DormTypePerYearPrice2Keys.csv")

# %%
#Left Union test on data
testing = pd.merge(Year2010_2011test, prices[["Building","10_11"]], how='left', on=["Building"])

# %%
testing
# Out:
#              Room Category                 Campus                  Building  \
# 0               Continuing  College Avenue Campus  Easton Avenue Apartments
# 1               Continuing  College Avenue Campus  Easton Avenue Apartments
# 2               Continuing      Livingston Campus          Quad I Res. Hall
# 3               Continuing      Livingston Campus          Quad I Res. Hall
# 4               Continuing            Cook Campus                    NEWELL
# 5               Continuing            Cook Campus                    NEWELL
# 6               Continuing            Cook Campus                    NEWELL
# 7               Continuing           Busch Campus             Davidson Hall
# 8               Continuing           Busch Campus             Davidson Hall
# 9               Continuing            Cook Campus                    NEWELL
# 10              Continuing            Cook Campus                    NEWELL
# ...

# %%
testing.to_csv("testing2.csv")

# %%
Year2010_2011
# Out:
#              Room Category                 Campus                  Building  \
# 0               Continuing  College Avenue Campus  Easton Avenue Apartments
# 1               Continuing      Livingston Campus          Quad I Res. Hall
# 2               Continuing            Cook Campus                    NEWELL
# 3               Continuing           Busch Campus             Davidson Hall
# 5               Continuing            Cook Campus                    NEWELL
# 6               Continuing           Busch Campus             Judson Suites
# 8               Continuing            Cook Campus                  NICHOLAS
# 9               Continuing           Busch Campus        Silvers Apartments
# 10     Continuing/Transfer      Livingston Campus         Quad II Res. Hall
# 11              Continuing        Douglass Campus      Katzenbach Res. Hall
# 12              Continuing           Busch Campus            Winkler Suites
# ...

# %%
Year2011_2012
# Out:
#       Room Category                 Campus                  Building  \
# 0        Continuing      Livingston Campus    Lynton Tower Res. Hall
# 1        Continuing           Busch Campus     Richardson Apartments
# 2        Continuing           Busch Campus            Winkler Suites
# 3        Continuing        Douglass Campus         Jameson Res. Hall
# 4        Continuing        Douglass Campus     Old Gibbons Res. Hall
# 5        Continuing        Douglass Campus      Henderson Apartments
# 7        Continuing           Busch Campus                 BEST Hall
# 8        Continuing      Livingston Campus        Quad III Res. Hall
# 9        Continuing           Busch Campus             Crosby Suites
# 10       Continuing      Livingston Campus        Quad III Res. Hall
# 11       Continuing  College Avenue Campus  Easton Avenue Apartments
# 13       Continuing  College Avenue Campus          Hardenbergh Hall
# 14       Continuing           Busch Campus             Davidson Hall
# ...

# %%
#function to merge price to all instances
def mergeprice(Year,PriceYear):
    return(pd.merge(Year, prices[["Building","Room Type", PriceYear]], how='left', on=["Building", "Room Type"]))

# %%
testing2 = mergeprice(testing,"10_11")

# %%
testing2
# Out:
#              Room Category                 Campus                  Building  \
# 0               Continuing  College Avenue Campus  Easton Avenue Apartments
# 1               Continuing  College Avenue Campus  Easton Avenue Apartments
# 2               Continuing      Livingston Campus          Quad I Res. Hall
# 3               Continuing      Livingston Campus          Quad I Res. Hall
# 4               Continuing            Cook Campus                    NEWELL
# 5               Continuing            Cook Campus                    NEWELL
# 6               Continuing            Cook Campus                    NEWELL
# 7               Continuing           Busch Campus             Davidson Hall
# 8               Continuing           Busch Campus             Davidson Hall
# 9               Continuing            Cook Campus                    NEWELL
# 10              Continuing            Cook Campus                    NEWELL
# ...

# %%
#Inner left Join to merge prices to Dataset
Year2010_2011Price = mergeprice(Year2010_2011,"10_11")
Year2011_2012Price = mergeprice(Year2011_2012,"11_12")
Year2012_2013Price = mergeprice(Year2012_2013,"12_13")
Year2013_2014Price = mergeprice(Year2013_2014,"13_14")
Year2014_2015Price = mergeprice(Year2014_2015,"14_15")
Year2015_2016Price = mergeprice(Year2015_2016,"15_16")
Year2016_2017Price = mergeprice(Year2016_2017,"16_17")
Year2017_2018Price = mergeprice(Year2017_2018,"17_18")

#Rename last column
Year2010_2011Price.columns.values[-1] = "Price"
Year2011_2012Price.columns.values[-1] = "Price"
Year2012_2013Price.columns.values[-1] = "Price"
Year2013_2014Price.columns.values[-1] = "Price"
Year2014_2015Price.columns.values[-1] = "Price"
Year2015_2016Price.columns.values[-1] = "Price"
Year2016_2017Price.columns.values[-1] = "Price"
Year2017_2018Price.columns.values[-1] = "Price"

# %%
Year2010_2011Price.iloc[:,-1]
# Out:
# 0        7354.0
# 1        6836.0
# 2        7310.0
# 3        6836.0
# 4        7310.0
# 5        6836.0
# 6        6836.0
# 7        7310.0
# 8        6836.0
# 9        6836.0
# 10       6836.0
# 11       6836.0
# 12       7354.0
# 13       6836.0
# 14       6836.0
# 15       7114.0
# 16       6836.0
# 17       6836.0
# 18       7310.0
# 19       6836.0
# 20       6836.0
# 21       7310.0
# 22       6836.0
# 23       6836.0
# 24       6836.0
# 25       6836.0
# 26       7354.0
# 27       6836.0
# 28       6836.0
# 29       7310.0
#           ...
# 13152    6836.0
# 13153    6836.0
# 13154    6836.0
# 13155    6836.0
# 13156    6836.0
# 13157    7310.0
# 13158    6836.0
# 13159    6836.0
# 13160    6836.0
# 13161    6836.0
# 13162    7310.0
# 13163    6836.0
# 13164    6836.0
# 13165    7310.0
# 13166    6836.0
# 13167    6836.0
# 13168    7114.0
# 13169    6836.0
# 13170    6836.0
# 13171    6836.0
# 13172    6836.0
# 13173    6836.0
# 13174    7114.0
# 13175    6836.0
# ...

# %%
#Binning: Categorizing Residence Hall Prices into threee bins
#Bins chosen upon reviewing 
#Lowest: 6836	7042	7042	7092	7163	7364	7490	7602
#Highest: 6984.365382	7194.83631	7410.6814	7463.299132	7538.016311	7749.539595	7882.13628	8000
 
def binning(col, cut_points, labels=None):
    #Define min and max values:
    minval = col.min()
    maxval = col.max()

    #create list by adding min and max to cut_points
    break_points = [minval] + cut_points + [maxval]

    #if no labels provided, use default labels 0 ... (n-1)
    if not labels:
        labels = range(len(cut_points)+1)

    #Binning using cut function of pandas
    colBin = pd.cut(col,bins=break_points,labels=labels,include_lowest=True)
    return colBin

#Binning Price:
cut_points2010_2011 = [6836,6984]
labels = ["low","avg","high",]
Year2010_2011Price["Price_Bin"] = binning(Year2010_2011Price.iloc[:,-1], cut_points2010_2011, labels)
cut_points2011_2012 = [7042,7194]
Year2011_2012Price["Price_Bin"] = binning(Year2011_2012Price.iloc[:,-1], cut_points2011_2012, labels)
cut_points2012_2013 = [7042,7410]
Year2012_2013Price["Price_Bin"] = binning(Year2012_2013Price.iloc[:,-1], cut_points2012_2013, labels)
cut_points2013_2014 = [7092,7463]
Year2013_2014Price["Price_Bin"] = binning(Year2013_2014Price.iloc[:,-1], cut_points2013_2014, labels)
cut_points2014_2015 = [7163,7538]
Year2014_2015Price["Price_Bin"] = binning(Year2014_2015Price.iloc[:,-1], cut_points2014_2015, labels)
cut_points2015_2016 = [7364,7749]
Year2015_2016Price["Price_Bin"] = binning(Year2015_2016Price.iloc[:,-1], cut_points2015_2016, labels)
cut_points2016_2017 = [7490,7882]
Year2016_2017Price["Price_Bin"] = binning(Year2016_2017Price.iloc[:,-1], cut_points2016_2017, labels)
cut_points2017_2018 = [7602,8000]
Year2017_2018Price["Price_Bin"] = binning(Year2017_2018Price.iloc[:,-1], cut_points2017_2018, labels)
#print pd.value_counts(data["LoanAmount_Bin"], sort=False)

# %%
Year2017_2018Price
# Out:
#       Room Category                 Campus                    Building  \
# 0        Continuing      Livingston Campus       Livingston Apartments
# 1        Continuing      Livingston Campus       Livingston Apartments
# 2        Continuing      Livingston Campus          Quad III Res. Hall
# 3        Continuing        Douglass Campus           Jameson Res. Hall
# 4            Family           Busch Campus          Nichols Apartments
# 5        Continuing      Livingston Campus            Quad I Res. Hall
# 6        Continuing           Busch Campus                   BEST Hall
# 7        Continuing           Busch Campus                   BEST Hall
# 8        Continuing      Livingston Campus      Lynton Tower Res. Hall
# 9        Continuing        Douglass Campus      Bunting-Cobb Res. Hall
# 10       Continuing           Busch Campus          Silvers Apartments
# 11       Continuing      Livingston Campus          Quad III Res. Hall
# ...

# %%
#Removing family dorm instances
Year2010_2011Price =Year2010_2011Price.loc[Year2010_2011Price['Room Category'] != "Family"]
Year2011_2012Price =Year2011_2012Price.loc[Year2011_2012Price['Room Category'] != "Family"]
Year2012_2013Price =Year2012_2013Price.loc[Year2012_2013Price['Room Category'] != "Family"]
Year2013_2014Price =Year2013_2014Price.loc[Year2013_2014Price['Room Category'] != "Family"]
Year2014_2015Price =Year2014_2015Price.loc[Year2014_2015Price['Room Category'] != "Family"]
Year2015_2016Price =Year2015_2016Price.loc[Year2015_2016Price['Room Category'] != "Family"]
Year2016_2017Price =Year2016_2017Price.loc[Year2016_2017Price['Room Category'] != "Family"]
Year2017_2018Price =Year2017_2018Price.loc[Year2017_2018Price['Room Category'] != "Family"]

# %%
#resetting indexes to anonimize data
Year2010_2011Price.reset_index
Year2011_2012Price.reset_index
Year2012_2013Price.reset_index
Year2013_2014Price.reset_index
Year2014_2015Price.reset_index
Year2015_2016Price.reset_index
Year2016_2017Price.reset_index
Year2017_2018Price.reset_index
# Out:
# <bound method DataFrame.reset_index of       Room Category                 Campus                    Building  \
# 0        Continuing      Livingston Campus       Livingston Apartments
# 1        Continuing      Livingston Campus       Livingston Apartments
# 2        Continuing      Livingston Campus          Quad III Res. Hall
# 3        Continuing        Douglass Campus           Jameson Res. Hall
# 5        Continuing      Livingston Campus            Quad I Res. Hall
# 6        Continuing           Busch Campus                   BEST Hall
# 7        Continuing           Busch Campus                   BEST Hall
# 8        Continuing      Livingston Campus      Lynton Tower Res. Hall
# 9        Continuing        Douglass Campus      Bunting-Cobb Res. Hall
# 10       Continuing           Busch Campus          Silvers Apartments
# 11       Continuing      Livingston Campus          Quad III Res. Hall
# 12       Continuing      Livingston Campus           Quad II Res. Hall
# ...

# %%
#Disregard, unsuccessful binning attempted

"""def pricecat2010(c):
  if c['Price'] < 1.0:
    return 'Full'
  elif c['used'] == 0.0:
    return 'Empty'
  elif 0.0 < c['used'] < 1.0:
    return 'Partial'
  else:
    return 'Undefined'

df = pd.DataFrame(data={'portion':[1, 2, 3, 4], 'used':[1.0, 0.3, 0.0, 0.8]})

df['alert'] = df.apply(alert, axis=1)"""
# Out:
# "def pricecat2010(c):\n  if c['Price'] < 1.0:\n    return 'Full'\n  elif c['used'] == 0.0:\n    return 'Empty'\n  elif 0.0 < c['used'] < 1.0:\n    return 'Partial'\n  else:\n    return 'Undefined'\n\ndf = pd.DataFrame(data={'portion':[1, 2, 3, 4], 'used':[1.0, 0.3, 0.0, 0.8]})\n\ndf['alert'] = df.apply(alert, axis=1)"

# %%
#merging all files with bins and prices bins
data_year1 = Year2010_2011Price
data_year1_all = data_year1.append([Year2011_2012Price, Year2012_2013Price,Year2013_2014Price,Year2014_2015Price,Year2015_2016Price,Year2016_2017Price,Year2017_2018Price],sort=False)
data_year1_all.columns
# Out:
# Index(['Room Category', 'Campus', 'Building', 'Wing', 'Room', 'Room Type',
#        'RUID', 'SURE_ReportingDt', 'Last Name', 'First Name', 'Gender',
#        'Admit Term', 'Class Year', 'Enrollment Term Referenced',
#        'Citizenship Status', 'Original State Residency',
#        'Original State Residency Category', 'Major Code', 'CIP Code',
#        'CIP Category', 'School', 'IPEDS Race/Ethnicity', 'Pell Grant Status',
#        'First Generation Status', 'Country of Origin', 'City', 'State',
#        'Confirmed LLC', 'Honors Indicator', 'Year_Of_Occupancy', 'Price',
#        'Price_Bin'],
#       dtype='object')

# %%
data_year1_all
# Out:
#              Room Category                 Campus                    Building  \
# 0               Continuing  College Avenue Campus    Easton Avenue Apartments
# 1               Continuing      Livingston Campus            Quad I Res. Hall
# 2               Continuing            Cook Campus                      NEWELL
# 3               Continuing           Busch Campus               Davidson Hall
# 4               Continuing            Cook Campus                      NEWELL
# 5               Continuing           Busch Campus               Judson Suites
# 6               Continuing            Cook Campus                    NICHOLAS
# 7               Continuing           Busch Campus          Silvers Apartments
# 8      Continuing/Transfer      Livingston Campus           Quad II Res. Hall
# 9               Continuing        Douglass Campus        Katzenbach Res. Hall
# 10              Continuing           Busch Campus              Winkler Suites
# ...

# %%
#Remove all buildings that do not have prices on undergraduates
data_year1_all =data_year1_all.loc[data_year1_all['Building'] != 'Marvin Apartments']
data_year1_all =data_year1_all.loc[data_year1_all['Building'] != 'Old Gibbons Res. Hall']
data_year1_all =data_year1_all.loc[data_year1_all['Building'] != 'UNIV. INN']

# %%
#File was removed to manually change values for HS. 26 and Jameson G on Excel
#Removed non-undergrad in excel as well that was found to be mislabeled
data_year1_all.to_csv("FinalMerge3.csv", index="False")

# %%
#Usuccesful Binning
"""def pricecat(c):
    if c['Price'] =< lower[c["Year_of_Occupancy"]]:
        return 'Low'
    elif c['Price'] => higher[c["Year_of_Occupancy"]]:
    return 'High'
  elif 0.0 < c['used'] < 1.0:
    return 'Partial'
  else:
    return 'Undefined'

df = pd.DataFrame(data={'portion':[1, 2, 3, 4], 'used':[1.0, 0.3, 0.0, 0.8]})

df['alert'] = df.apply(alert, axis=1)"""

# %%
#data_year1_all= data_year1_all.rename(index=str, columns={"Price": "Year_Price"})

# %%
#Reimporting file 
data_year1_all = pd.read_csv("FinalMerge3shared.csv")
# Out:
# C:\Users\ivani\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_year1_all.dtypes
# Out:
# Room Category                         object
# Campus                                object
# Building                              object
# Wing                                  object
# Room                                  object
# Room Type                             object
# RUID                                  object
# SURE_ReportingDt                       int64
# Last Name                             object
# First Name                            object
# Gender                                object
# Admit Term                           float64
# Class Year                            object
# Enrollment Term Referenced            object
# Citizenship Status                    object
# Original State Residency              object
# Original State Residency Category     object
# Major Code                            object
# CIP Code                              object
# CIP Category                          object
# School                                object
# ...

# %%
#Normalizing Country
#w.female[w.female == 'female'] = 1 
data_year1_all= data_year1_all.rename(index=str, columns={"Country of Origin": "Country"})

# %%
data_year1_all.Country[data_year1_all.Country == 'USA'] = 'United States'
data_year1_all.Country[data_year1_all.Country == 'AS'] = 'Australia'
data_year1_all.Country[data_year1_all.Country == 'UNITED STATES'] = 'United States'
data_year1_all.Country[data_year1_all.Country == 'AR'] = 'Argentina'
data_year1_all.Country[data_year1_all.Country == 'USA'] = 'United States'
data_year1_all.Country[data_year1_all.Country == 'AU'] = 'Austria'
data_year1_all.Country[data_year1_all.Country == 'BB'] = 'Barbados'
data_year1_all.Country[data_year1_all.Country == 'BD'] = 'Bermuda'
data_year1_all.Country[data_year1_all.Country == 'BF'] = 'Bahamas'
data_year1_all.Country[data_year1_all.Country == 'BG'] = 'Bangladesh'
data_year1_all.Country[data_year1_all.Country == 'BH'] = 'Belize'
data_year1_all.Country[data_year1_all.Country == 'BL'] = 'Bolivia'
data_year1_all.Country[data_year1_all.Country == 'BM'] = 'Burma'
data_year1_all.Country[data_year1_all.Country == 'BR'] = 'Brazil'
data_year1_all.Country[data_year1_all.Country == 'CA'] = 'Canada'
data_year1_all.Country[data_year1_all.Country == 'CE'] = 'Sri Lanka'
data_year1_all.Country[data_year1_all.Country == 'CH'] = 'China'
data_year1_all.Country[data_year1_all.Country == 'CJ'] = 'Cayman Islands'
data_year1_all.Country[data_year1_all.Country == 'CO'] = 'Colombia'
data_year1_all.Country[data_year1_all.Country == 'CY'] = 'Cyprus'
data_year1_all.Country[data_year1_all.Country == 'DA'] = 'Denmark'
data_year1_all.Country[data_year1_all.Country == 'DR'] = 'Dominican Republic'
data_year1_all.Country[data_year1_all.Country == 'EC'] = 'Ecuador'
data_year1_all.Country[data_year1_all.Country == 'EG'] = 'Egypt'
data_year1_all.Country[data_year1_all.Country == 'EZ'] = 'Czech Republic'
data_year1_all.Country[data_year1_all.Country == 'FI'] = 'Finland'
data_year1_all.Country[data_year1_all.Country == 'FR'] = 'France'
data_year1_all.Country[data_year1_all.Country == 'FRANCE'] = 'France'
data_year1_all.Country[data_year1_all.Country == 'GH'] = 'Ghana'
data_year1_all.Country[data_year1_all.Country == 'GQ'] = 'Guam'
data_year1_all.Country[data_year1_all.Country == 'GR'] = 'Greece'
data_year1_all.Country[data_year1_all.Country == 'GU'] = 'Guatemala'
data_year1_all.Country[data_year1_all.Country =='HA'] = 'Haiti'
data_year1_all.Country[data_year1_all.Country == 'HK'] = 'Hong Kong'
data_year1_all.Country[data_year1_all.Country == 'ID'] = 'Indonesia'
data_year1_all.Country[data_year1_all.Country == 'IN'] = 'India'
data_year1_all.Country[data_year1_all.Country == 'IR'] = 'Iran'
data_year1_all.Country[data_year1_all.Country == 'IRAN'] = 'Iran'
data_year1_all.Country[data_year1_all.Country == 'IS'] = 'Israel'
data_year1_all.Country[data_year1_all.Country == 'IT'] = 'Italy'
data_year1_all.Country[data_year1_all.Country == 'JA'] = 'Japan'
data_year1_all.Country[data_year1_all.Country == 'JM'] = 'Jamaica'
data_year1_all.Country[data_year1_all.Country == 'KE'] = 'Kenya'
data_year1_all.Country[data_year1_all.Country == 'KENYA'] = 'Kenya'
data_year1_all.Country[data_year1_all.Country == 'Kiribati'] = 'South Korea'
data_year1_all.Country[data_year1_all.Country == 'KOREA'] = 'South Korea'
data_year1_all.Country[data_year1_all.Country == 'KS'] = 'South Korea'
data_year1_all.Country[data_year1_all.Country == 'KU'] = 'Kuwait'
data_year1_all.Country[data_year1_all.Country == 'LE'] = 'Lebanon'
data_year1_all.Country[data_year1_all.Country == 'LH'] = 'Lithuania'
data_year1_all.Country[data_year1_all.Country == 'LI'] = 'Liberia'
data_year1_all.Country[data_year1_all.Country == 'MC'] = 'Macao'
data_year1_all.Country[data_year1_all.Country == 'MG'] = 'Mongolia'
data_year1_all.Country[data_year1_all.Country == 'MC'] = 'Macao'
data_year1_all.Country[data_year1_all.Country == 'MN'] = 'Monaco'
data_year1_all.Country[data_year1_all.Country == 'MU'] = 'Oman'
data_year1_all.Country[data_year1_all.Country == 'MC'] = 'Macao'
data_year1_all.Country[data_year1_all.Country == 'MX'] = 'Mexico'
data_year1_all.Country[data_year1_all.Country == 'MY'] = 'Malaysia'
data_year1_all.Country[data_year1_all.Country == 'NI'] = 'Nigeria'
data_year1_all.Country[data_year1_all.Country == 'NL'] = 'Netherlands'
data_year1_all.Country[data_year1_all.Country == 'NO'] = 'Norway'
data_year1_all.Country[data_year1_all.Country == 'PK'] = 'Pakistan'
data_year1_all.Country[data_year1_all.Country == 'PL'] = 'Poland'
data_year1_all.Country[data_year1_all.Country == 'PQ'] = 'Puerto Rico'
data_year1_all.Country[data_year1_all.Country == 'RB'] = 'Serbia'
data_year1_all.Country[data_year1_all.Country == 'RP'] = 'Philippines'
data_year1_all.Country[data_year1_all.Country == 'RS'] = 'Russia'
data_year1_all.Country[data_year1_all.Country == 'RW'] = 'Rwanda'
data_year1_all.Country[data_year1_all.Country == 'SA'] = 'Saudi Arabia'
data_year1_all.Country[data_year1_all.Country == 'SF'] = 'South Africa'
data_year1_all.Country[data_year1_all.Country == 'SG'] = 'Senegal'
data_year1_all.Country[data_year1_all.Country == 'PK'] = 'Pakistan'
data_year1_all.Country[data_year1_all.Country == 'SN'] = 'Singapore'
data_year1_all.Country[data_year1_all.Country == 'SP'] = 'Spain'
data_year1_all.Country[data_year1_all.Country == 'SPAIN'] = 'Spain'
data_year1_all.Country[data_year1_all.Country == 'ST'] = 'Saint Lucia'
data_year1_all.Country[data_year1_all.Country == 'SW'] = 'Sweden'
data_year1_all.Country[data_year1_all.Country == 'SZ'] = 'Switzerland'
data_year1_all.Country[data_year1_all.Country == 'TAIWAN'] = 'Taiwan'
data_year1_all.Country[data_year1_all.Country == 'TD'] = 'Trinidad & Tobago'
data_year1_all.Country[data_year1_all.Country == 'TH'] = 'Thailand'
data_year1_all.Country[data_year1_all.Country == 'TS'] = 'Tunisia'
data_year1_all.Country[data_year1_all.Country == 'TU'] = 'Turkey'
data_year1_all.Country[data_year1_all.Country == 'TW'] = 'Taiwan'
data_year1_all.Country[data_year1_all.Country == 'UG'] = 'Uganda'
data_year1_all.Country[data_year1_all.Country == 'UK'] = 'United Kingdom'
data_year1_all.Country[data_year1_all.Country == 'UNITED KINGDOM'] = 'United Kingdom'
data_year1_all.Country[data_year1_all.Country == 'VE'] = 'Venezuela'
data_year1_all.Country[data_year1_all.Country == 'VI'] = 'Virgin Islands'
data_year1_all.Country[data_year1_all.Country == 'VI'] = 'Thailand'
data_year1_all.Country[data_year1_all.Country == 'VM'] = 'Vietnam'
data_year1_all.Country[data_year1_all.Country == 'VQ'] = 'Virgin Islands'
data_year1_all.Country[data_year1_all.Country == 'CHINA'] = 'China'
data_year1_all.Country[data_year1_all.Country == 'JAPAN'] = 'Japan'
data_year1_all.Country[data_year1_all.Country == 'IRAQ'] = 'Iraq'
# Out:
# C:\Users\ivani\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\ivani\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\ivani\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ...

# %%
data_year1_all.Country.unique()
# Out:
# array([nan, 'United States', 'Nigeria', 'Bangladesh', 'South Korea',
#        'China', 'Lithuania', 'Malaysia', 'Kuwait', 'Taiwan', 'Norway',
#        'India', 'Haiti', 'Hong Kong', 'Mexico', 'Bolivia', 'Vietnam',
#        'Comoro Islands', 'Canada', 'Guam', 'Finland', 'Colombia',
#        'Switzerland', 'Cyprus', 'United Arab Emirates', 'Belize',
#        'Singapore', 'France', 'Iran', 'Turkey', 'Thailand', 'Greece',
#        'Afghanistan', 'Sweden', 'Saudi Arabia', 'Australia',
#        'Czech Republic', 'Venezuela', 'United Kingdom', 'Jamaica',
#        'Philippines', 'Egypt', 'Puerto Rico', 'Japan', 'Guatemala',
#        'Trinidad & Tobago', 'Spain', 'Dominican Republic', 'Monaco',
#        'Oman', 'Indonesia', 'South Africa', 'Virgin Islands',
#        'Us Misc Pac Is', 'Brazil', 'Pakistan', 'Russia', 'Azerbaijan',
#        'Ecuador', 'Lebanon', 'Burma', 'Tunisia', 'Kenya', 'Italy',
#        'Ghana', 'Costa Rica', 'Sri Lanka', 'Israel', 'Netherlands',
# ...

# %%
data_year1_all.to_excel("FinalDataSet.xlsx")
